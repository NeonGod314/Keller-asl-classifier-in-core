# %%
#imports
import pickle
import numpy as np
from dnn_utils import *
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
# Out:
# C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
% matplotlib inline
np.random.seed(1)

# %%
n_Class, class_dict, train_dataset = load_images('train')
_, _, test_dataset = load_images('test')
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset(train_dataset, test_dataset)

# %%
#serializzable file for storing class name and it's respective label
pickle_generator(class_dict)

# %%
index = 1
plt.imshow(X_train_orig[index])
print ("y= " + str(np.squeeze(Y_train_orig[:,index])))
# Out:
# y= 0

# %%
X_train = X_train_orig/255.
X_test  = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, n_Class).T
Y_test  = convert_to_one_hot(Y_test_orig, n_Class).T 
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
conv_layers = {}
# Out:
# number of training examples = 1766
# number of test examples = 1703
# X_train shape: (1766, 64, 64, 3)
# Y_train shape: (1766, 4)
# X_test shape: (1703, 64, 64, 3)
# Y_test shape: (1703, 4)

# %%
def create_placeholders(n_H0, n_W0, n_C0, n_y):
    X = tf.placeholder(tf.float32, shape = [None, n_H0, n_W0, n_C0], name = "myInput")
    Y = tf.placeholder(tf.float32, shape = [None, n_y],name = "myOutput")
    print (X)
    return X, Y

# %%
'''test block'''
X, Y = create_placeholders(1584, 1224, 3, 2)
print ("X= " + str(X))
print ("Y= " + str(Y))
# Out:
# Tensor("myInput:0", shape=(?, 1584, 1224, 3), dtype=float32)
# X= Tensor("myInput:0", shape=(?, 1584, 1224, 3), dtype=float32)
# Y= Tensor("myOutput:0", shape=(?, 2), dtype=float32)

# %%
def initialize_parameters():
    tf.set_random_seed(1)
    
    W1 = tf.get_variable('W1', [4, 4, 3, 8], initializer = tf.contrib.layers.xavier_initializer(seed = 0))
    W2 = tf.get_variable('W2', [2, 2, 8, 16],initializer = tf.contrib.layers.xavier_initializer(seed = 0))
    
    parameters = {"W1": W1,
                  "W2": W2}
    
    return parameters

# %%
'''test block'''
tf.reset_default_graph()
with tf.Session() as sess_test:
    parameters = initialize_parameters()
    init = tf.global_variables_initializer()
    sess_test.run(init)
    xx=parameters["W1"].eval()[1,1,1]
    print("W1 = " + str(parameters["W1"].eval()[1,1,1]))
    print("W2 = " + str(parameters["W2"].eval()[1,1,1]))
# Out:
# W1 = [ 0.00131723  0.1417614  -0.04434952  0.09197326  0.14984085 -0.03514394
#  -0.06847463  0.05245192]
# W2 = [-0.08566415  0.17750949  0.11974221  0.16773748 -0.0830943  -0.08058
#  -0.00577033 -0.14643836  0.24162132 -0.05857408 -0.19055021  0.1345228
#  -0.22779644 -0.1601823  -0.16117483 -0.10286498]

# %%
def forward_propagation(X, parameters):
    W1 = parameters['W1']
    W2 = parameters['W2']
    
    Z1 = tf.nn.conv2d(X, W1, strides = [1,1,1,1], padding = 'SAME')
    A1 = tf.nn.relu(Z1)
    P1 = tf.nn.max_pool(A1, ksize = [1, 8, 8, 1], strides = [1, 8, 8, 1], padding = 'SAME')
    Z2 = tf.nn.conv2d(P1, W2, strides = [1, 1, 1, 1], padding = 'SAME')
    A2 = tf.nn.relu(Z2)
    P2 = tf.nn.max_pool(A2, ksize = [1, 4, 4, 1], strides = [1,4,4,1], padding = 'SAME')
    
    P2 = tf.contrib.layers.flatten(P2)
    
    Z3 = tf.contrib.layers.fully_connected(P2, n_Class, activation_fn = None)
    
    return Z3

# %%
'''test block'''
tf.reset_default_graph()

with tf.Session() as sess:
    np.random.seed(1)
    X, Y = create_placeholders(1000, 1000, 3, 3)
    parameters = initialize_parameters()
    Z3 = forward_propagation(X, parameters)
    init = tf.global_variables_initializer()
    sess.run(init)
    a = sess.run(Z3, {X: np.random.randn(3,1000,1000,3), Y: np.random.randn(3,3)})
    print("Z3 = " + str(a))
# Out:
# Tensor("myInput:0", shape=(?, 1000, 1000, 3), dtype=float32)
# Z3 = [[-0.42086345  2.7334027  -1.8381953   1.9200337 ]
#  [-0.55439365  2.5850239  -1.5409074   1.567951  ]
#  [-0.2924322   2.6158438  -1.6435757   2.0210223 ]]

# %%
def compute_cost(Z3, Y):
    cost = tf.nn.softmax_cross_entropy_with_logits(logits = Z3, labels =Y)
    cost = tf.reduce_mean(cost)
    
    return cost

# %%
'''test block'''
tf.reset_default_graph()

with tf.Session() as sess:
    np.random.seed(1)
    X, Y = create_placeholders(64, 64, 3, 3)
    parameters = initialize_parameters()
    Z3   = forward_propagation(X, parameters)
    cost = compute_cost(Z3, Y)
    init = tf.global_variables_initializer()
    sess.run(init)
    a = sess.run(cost,{X: np.random.randn(4, 64, 64, 3), Y: np.random.randn(4,3)})
    print("cost= " + str(a))
# Out:
# Tensor("myInput:0", shape=(?, 64, 64, 3), dtype=float32)
# WARNING:tensorflow:From <ipython-input-12-4bd9710213a7>:2: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# InvalidArgumentError: logits and labels must be broadcastable: logits_size=[4,4] labels_size=[4,3]
# 	 [[Node: softmax_cross_entropy_with_logits_sg = SoftmaxCrossEntropyWithLogits[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"](softmax_cross_entropy_with_logits_sg/Reshape, softmax_cross_entropy_with_logits_sg/Reshape_1)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-13-b0f9950af1e0> in <module>()
#      10     init = tf.global_variables_initializer()
#      11     sess.run(init)
# ---> 12     a = sess.run(cost,{X: np.random.randn(4, 64, 64, 3), Y: np.random.randn(4,3)})
#      13     print("cost= " + str(a))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# InvalidArgumentError: logits and labels must be broadcastable: logits_size=[4,4] labels_size=[4,3]
# 	 [[Node: softmax_cross_entropy_with_logits_sg = SoftmaxCrossEntropyWithLogits[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"](softmax_cross_entropy_with_logits_sg/Reshape, softmax_cross_entropy_with_logits_sg/Reshape_1)]]
#
# Caused by op 'softmax_cross_entropy_with_logits_sg', defined at:
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-b0f9950af1e0>", line 9, in <module>
#     cost = compute_cost(Z3, Y)
#   File "<ipython-input-12-4bd9710213a7>", line 2, in compute_cost
#     cost = tf.nn.softmax_cross_entropy_with_logits(logits = Z3, labels =Y)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 250, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 1959, in softmax_cross_entropy_with_logits
#     labels=labels, logits=logits, dim=dim, name=name)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 1873, in softmax_cross_entropy_with_logits_v2
#     precise_logits, labels, name=name)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py", line 7168, in softmax_cross_entropy_with_logits
#     name=name)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "C:\Users\shubhamkumar.singh\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): logits and labels must be broadcastable: logits_size=[4,4] labels_size=[4,3]
# 	 [[Node: softmax_cross_entropy_with_logits_sg = SoftmaxCrossEntropyWithLogits[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"](softmax_cross_entropy_with_logits_sg/Reshape, softmax_cross_entropy_with_logits_sg/Reshape_1)]]

# %%
def model(X_train, Y_train, X_test, Y_test, learning_rate = 0.009, num_epochs = 16, minibatch_size = 8, print_cost = True):
    
    ops.reset_default_graph() # to rerun the model without overwritting tf variables
    tf.set_random_seed(1)
    seed = 3 #numpy seed
    print (X_train.shape)
    (m, n_H0, n_W0, n_C0) = X_train.shape
    n_y = Y_train.shape[1]
    costs = []
    
    X, Y =create_placeholders(n_H0, n_W0, n_C0, n_y)
    parameters = initialize_parameters()
    
    Z3 = forward_propagation(X, parameters)
    print (Z3)
    cost = compute_cost(Z3, Y)
    
    optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(cost)
    
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()
    
    with  tf.Session() as sess:
        sess.run(init)
        
        for epoch in range(num_epochs):
            minibatch_cost = 0.
            num_minibatches = int(m / minibatch_size) #number of minibatch size intrainSet
            
            seed = seed + 1
            minibatches = random_mini_batches(X_train, Y_train, minibatch_size, seed)
            
            for minibatch in minibatches:
                
                (minibatch_X, minibatch_Y) = minibatch
                _, temp_cost = sess.run([optimizer, cost], feed_dict = {X: minibatch_X, Y: minibatch_Y})
                minibatch_cost += temp_cost/num_minibatches
                
                if print_cost == True and epoch % 5 == 0:
                    print ("Cost After epoch %i : %f" %(epoch, minibatch_cost))
                if print_cost == True and epoch % 1 == 0:
                    costs.append(minibatch_cost)    
                                     
        plt.plot(np.squeeze(costs))
        plt.ylabel('cost')
        plt.xlabel('iteration per 10')
        plt.title("Learning rate =" + str(learning_rate))
        plt.show()

        predict_op = tf.argmax(Z3, 1, name = 'predict_op')
        correct_prediction = tf.equal(predict_op, tf.argmax(Y, 1)) 

        accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
        print(accuracy)
        train_accuracy = accuracy.eval({X: X_train, Y: Y_train})
        test_accuracy = accuracy.eval({X: X_test, Y: Y_test})
        print("Train Accuracy:", train_accuracy)
        print("Test Accuracy:", test_accuracy)                                    

        save_path = saver.save(sess, "./chkpt_save/final_model.ckpt")
        tf.saved_model.simple_save(sess, './xoxo2/',
                                   inputs = {"x":X},
                                   outputs = {"y":Y})
        return train_accuracy, test_accuracy, parameters

# %%
_, _, parameters = model(X_train, Y_train, X_test, Y_test)
# Out:
# (1766, 64, 64, 3)
# Tensor("myInput:0", shape=(?, 64, 64, 3), dtype=float32)
# Tensor("fully_connected/BiasAdd:0", shape=(?, 4), dtype=float32)
# Cost After epoch 0 : 0.007023
# Cost After epoch 0 : 0.013410
# Cost After epoch 0 : 0.019959
# Cost After epoch 0 : 0.026204
# Cost After epoch 0 : 0.032637
# Cost After epoch 0 : 0.038811
# Cost After epoch 0 : 0.044771
# Cost After epoch 0 : 0.051366
# Cost After epoch 0 : 0.058139
# Cost After epoch 0 : 0.064660
# Cost After epoch 0 : 0.070928
# Cost After epoch 0 : 0.076826
# Cost After epoch 0 : 0.083158
# Cost After epoch 0 : 0.089612
# Cost After epoch 0 : 0.095855
# Cost After epoch 0 : 0.101792
# Cost After epoch 0 : 0.107951
# Cost After epoch 0 : 0.113693
# Cost After epoch 0 : 0.119932
# Cost After epoch 0 : 0.126222
# Cost After epoch 0 : 0.132057
# Cost After epoch 0 : 0.138142
# Cost After epoch 0 : 0.144179
# Cost After epoch 0 : 0.150885
# Cost After epoch 0 : 0.157141
# Cost After epoch 0 : 0.163425
# Cost After epoch 0 : 0.169342
# Cost After epoch 0 : 0.175539
# Cost After epoch 0 : 0.181219
# Cost After epoch 0 : 0.187310
# Cost After epoch 0 : 0.193459
# Cost After epoch 0 : 0.199129
# Cost After epoch 0 : 0.205530
# Cost After epoch 0 : 0.211409
# Cost After epoch 0 : 0.216961
# Cost After epoch 0 : 0.223096
# Cost After epoch 0 : 0.228523
# Cost After epoch 0 : 0.235047
# Cost After epoch 0 : 0.240278
# Cost After epoch 0 : 0.247286
# Cost After epoch 0 : 0.252851
# Cost After epoch 0 : 0.258013
# Cost After epoch 0 : 0.263086
# Cost After epoch 0 : 0.268590
# Cost After epoch 0 : 0.274551
# Cost After epoch 0 : 0.280172
# Cost After epoch 0 : 0.285476
# Cost After epoch 0 : 0.291325
# Cost After epoch 0 : 0.296460
# Cost After epoch 0 : 0.301664
# Cost After epoch 0 : 0.306841
# Cost After epoch 0 : 0.311869
# Cost After epoch 0 : 0.317464
# Cost After epoch 0 : 0.322844
# Cost After epoch 0 : 0.326969
# Cost After epoch 0 : 0.333110
# Cost After epoch 0 : 0.338473
# Cost After epoch 0 : 0.344962
# Cost After epoch 0 : 0.350008
# Cost After epoch 0 : 0.355401
# Cost After epoch 0 : 0.360067
# Cost After epoch 0 : 0.364981
# Cost After epoch 0 : 0.368684
# Cost After epoch 0 : 0.374260
# Cost After epoch 0 : 0.377926
# Cost After epoch 0 : 0.383617
# Cost After epoch 0 : 0.388299
# Cost After epoch 0 : 0.393179
# Cost After epoch 0 : 0.400389
# Cost After epoch 0 : 0.404863
# Cost After epoch 0 : 0.408622
# Cost After epoch 0 : 0.414891
# Cost After epoch 0 : 0.422053
# Cost After epoch 0 : 0.425979
# Cost After epoch 0 : 0.430906
# Cost After epoch 0 : 0.434839
# Cost After epoch 0 : 0.439950
# Cost After epoch 0 : 0.445756
# Cost After epoch 0 : 0.448991
# Cost After epoch 0 : 0.454672
# Cost After epoch 0 : 0.458817
# Cost After epoch 0 : 0.465530
# Cost After epoch 0 : 0.472822
# Cost After epoch 0 : 0.478564
# Cost After epoch 0 : 0.483229
# Cost After epoch 0 : 0.488972
# Cost After epoch 0 : 0.493954
# Cost After epoch 0 : 0.498524
# Cost After epoch 0 : 0.503297
# Cost After epoch 0 : 0.508612
# Cost After epoch 0 : 0.512823
# Cost After epoch 0 : 0.517973
# Cost After epoch 0 : 0.522097
# Cost After epoch 0 : 0.527112
# Cost After epoch 0 : 0.530904
# Cost After epoch 0 : 0.535000
# Cost After epoch 0 : 0.538501
# Cost After epoch 0 : 0.544726
# Cost After epoch 0 : 0.548902
# Cost After epoch 0 : 0.553911
# Cost After epoch 0 : 0.558095
# Cost After epoch 0 : 0.561533
# Cost After epoch 0 : 0.565829
# Cost After epoch 0 : 0.568796
# Cost After epoch 0 : 0.572857
# Cost After epoch 0 : 0.577296
# Cost After epoch 0 : 0.580827
# Cost After epoch 0 : 0.585140
# Cost After epoch 0 : 0.588205
# Cost After epoch 0 : 0.590940
# Cost After epoch 0 : 0.594004
# Cost After epoch 0 : 0.597326
# Cost After epoch 0 : 0.601946
# Cost After epoch 0 : 0.603764
# Cost After epoch 0 : 0.608373
# Cost After epoch 0 : 0.612288
# Cost After epoch 0 : 0.616844
# Cost After epoch 0 : 0.619762
# Cost After epoch 0 : 0.625846
# Cost After epoch 0 : 0.630786
# Cost After epoch 0 : 0.633643
# Cost After epoch 0 : 0.637777
# Cost After epoch 0 : 0.641689
# Cost After epoch 0 : 0.646418
# Cost After epoch 0 : 0.650705
# Cost After epoch 0 : 0.655950
# Cost After epoch 0 : 0.660041
# Cost After epoch 0 : 0.664584
# Cost After epoch 0 : 0.667969
# Cost After epoch 0 : 0.672359
# Cost After epoch 0 : 0.675398
# Cost After epoch 0 : 0.678175
# Cost After epoch 0 : 0.680839
# Cost After epoch 0 : 0.685362
# Cost After epoch 0 : 0.689286
# Cost After epoch 0 : 0.691923
# Cost After epoch 0 : 0.694464
# Cost After epoch 0 : 0.696676
# Cost After epoch 0 : 0.699519
# Cost After epoch 0 : 0.701763
# Cost After epoch 0 : 0.705472
# Cost After epoch 0 : 0.711813
# Cost After epoch 0 : 0.715361
# Cost After epoch 0 : 0.719416
# Cost After epoch 0 : 0.722797
# Cost After epoch 0 : 0.726143
# Cost After epoch 0 : 0.728738
# Cost After epoch 0 : 0.732795
# Cost After epoch 0 : 0.738152
# Cost After epoch 0 : 0.739786
# Cost After epoch 0 : 0.742968
# Cost After epoch 0 : 0.746796
# Cost After epoch 0 : 0.750440
# Cost After epoch 0 : 0.753587
# Cost After epoch 0 : 0.756332
# Cost After epoch 0 : 0.758853
# Cost After epoch 0 : 0.762534
# Cost After epoch 0 : 0.765185
# Cost After epoch 0 : 0.768011
# Cost After epoch 0 : 0.773037
# Cost After epoch 0 : 0.777115
# Cost After epoch 0 : 0.779032
# Cost After epoch 0 : 0.781502
# Cost After epoch 0 : 0.787126
# Cost After epoch 0 : 0.791506
# Cost After epoch 0 : 0.796156
# Cost After epoch 0 : 0.798022
# Cost After epoch 0 : 0.800337
# Cost After epoch 0 : 0.801941
# Cost After epoch 0 : 0.804767
# Cost After epoch 0 : 0.807937
# Cost After epoch 0 : 0.809467
# Cost After epoch 0 : 0.811994
# Cost After epoch 0 : 0.815470
# Cost After epoch 0 : 0.818920
# Cost After epoch 0 : 0.822382
# Cost After epoch 0 : 0.826710
# Cost After epoch 0 : 0.829828
# Cost After epoch 0 : 0.833567
# Cost After epoch 0 : 0.836826
# Cost After epoch 0 : 0.840209
# Cost After epoch 0 : 0.843480
# Cost After epoch 0 : 0.846806
# Cost After epoch 0 : 0.851707
# Cost After epoch 0 : 0.853396
# Cost After epoch 0 : 0.855697
# Cost After epoch 0 : 0.858290
# Cost After epoch 0 : 0.859617
# Cost After epoch 0 : 0.862690
# Cost After epoch 0 : 0.866500
# Cost After epoch 0 : 0.867417
# Cost After epoch 0 : 0.869116
# Cost After epoch 0 : 0.871277
# Cost After epoch 0 : 0.872315
# Cost After epoch 0 : 0.875228
# Cost After epoch 0 : 0.880379
# Cost After epoch 0 : 0.882298
# Cost After epoch 0 : 0.883037
# Cost After epoch 0 : 0.886338
# Cost After epoch 0 : 0.887401
# Cost After epoch 0 : 0.889218
# Cost After epoch 0 : 0.891081
# Cost After epoch 0 : 0.891624
# Cost After epoch 0 : 0.895581
# Cost After epoch 0 : 0.897937
# Cost After epoch 0 : 0.900622
# Cost After epoch 0 : 0.902398
# Cost After epoch 0 : 0.903708
# Cost After epoch 0 : 0.904572
# Cost After epoch 0 : 0.905651
# Cost After epoch 0 : 0.907915
# Cost After epoch 0 : 0.910989
# Cost After epoch 0 : 0.914005
# Cost After epoch 0 : 0.915484
# Cost After epoch 0 : 0.917118
# Cost After epoch 0 : 0.918659
# Cost After epoch 0 : 0.921946
# Cost After epoch 0 : 0.923930
# Cost After epoch 0 : 0.924289
# Cost After epoch 0 : 0.926631
# Cost After epoch 0 : 0.933360
# Cost After epoch 5 : 0.000044
# Cost After epoch 5 : 0.000226
# Cost After epoch 5 : 0.000496
# Cost After epoch 5 : 0.000984
# Cost After epoch 5 : 0.008271
# Cost After epoch 5 : 0.008345
# Cost After epoch 5 : 0.009121
# Cost After epoch 5 : 0.009368
# Cost After epoch 5 : 0.009397
# Cost After epoch 5 : 0.009851
# Cost After epoch 5 : 0.010838
# Cost After epoch 5 : 0.010899
# Cost After epoch 5 : 0.012463
# Cost After epoch 5 : 0.014193
# Cost After epoch 5 : 0.016030
# Cost After epoch 5 : 0.017801
# Cost After epoch 5 : 0.018080
# Cost After epoch 5 : 0.018118
# Cost After epoch 5 : 0.018288
# Cost After epoch 5 : 0.018492
# Cost After epoch 5 : 0.018657
# Cost After epoch 5 : 0.018695
# Cost After epoch 5 : 0.019862
# Cost After epoch 5 : 0.020330
# Cost After epoch 5 : 0.021312
# Cost After epoch 5 : 0.021396
# Cost After epoch 5 : 0.021528
# Cost After epoch 5 : 0.024561
# Cost After epoch 5 : 0.024571
# Cost After epoch 5 : 0.025358
# Cost After epoch 5 : 0.026451
# Cost After epoch 5 : 0.026482
# Cost After epoch 5 : 0.026597
# Cost After epoch 5 : 0.028219
# Cost After epoch 5 : 0.028450
# Cost After epoch 5 : 0.028989
# Cost After epoch 5 : 0.031431
# Cost After epoch 5 : 0.032362
# Cost After epoch 5 : 0.033893
# Cost After epoch 5 : 0.034680
# Cost After epoch 5 : 0.034875
# Cost After epoch 5 : 0.034910
# Cost After epoch 5 : 0.034973
# Cost After epoch 5 : 0.036060
# Cost After epoch 5 : 0.036549
# Cost After epoch 5 : 0.036552
# Cost After epoch 5 : 0.038575
# Cost After epoch 5 : 0.038752
# Cost After epoch 5 : 0.039827
# Cost After epoch 5 : 0.039853
# Cost After epoch 5 : 0.040815
# Cost After epoch 5 : 0.040989
# Cost After epoch 5 : 0.041081
# Cost After epoch 5 : 0.041337
# Cost After epoch 5 : 0.041438
# Cost After epoch 5 : 0.041816
# Cost After epoch 5 : 0.043885
# Cost After epoch 5 : 0.044400
# Cost After epoch 5 : 0.044510
# Cost After epoch 5 : 0.045960
# Cost After epoch 5 : 0.046139
# Cost After epoch 5 : 0.046256
# Cost After epoch 5 : 0.046505
# Cost After epoch 5 : 0.046711
# Cost After epoch 5 : 0.046841
# Cost After epoch 5 : 0.047489
# Cost After epoch 5 : 0.047999
# Cost After epoch 5 : 0.048298
# Cost After epoch 5 : 0.048911
# Cost After epoch 5 : 0.049061
# Cost After epoch 5 : 0.049079
# Cost After epoch 5 : 0.049896
# Cost After epoch 5 : 0.050049
# Cost After epoch 5 : 0.050062
# Cost After epoch 5 : 0.050160
# Cost After epoch 5 : 0.050488
# Cost After epoch 5 : 0.050972
# Cost After epoch 5 : 0.052197
# Cost After epoch 5 : 0.052374
# Cost After epoch 5 : 0.052644
# Cost After epoch 5 : 0.053759
# Cost After epoch 5 : 0.054646
# Cost After epoch 5 : 0.056367
# Cost After epoch 5 : 0.056574
# Cost After epoch 5 : 0.056659
# Cost After epoch 5 : 0.056853
# Cost After epoch 5 : 0.056916
# Cost After epoch 5 : 0.057268
# Cost After epoch 5 : 0.057349
# Cost After epoch 5 : 0.057405
# Cost After epoch 5 : 0.057420
# Cost After epoch 5 : 0.057563
# Cost After epoch 5 : 0.059292
# Cost After epoch 5 : 0.060256
# Cost After epoch 5 : 0.060367
# Cost After epoch 5 : 0.060408
# Cost After epoch 5 : 0.060759
# Cost After epoch 5 : 0.060804
# Cost After epoch 5 : 0.064120
# Cost After epoch 5 : 0.064350
# Cost After epoch 5 : 0.064415
# Cost After epoch 5 : 0.064944
# Cost After epoch 5 : 0.066225
# Cost After epoch 5 : 0.066304
# Cost After epoch 5 : 0.066852
# Cost After epoch 5 : 0.067716
# Cost After epoch 5 : 0.069336
# Cost After epoch 5 : 0.069983
# Cost After epoch 5 : 0.071135
# Cost After epoch 5 : 0.071217
# Cost After epoch 5 : 0.071868
# Cost After epoch 5 : 0.075220
# Cost After epoch 5 : 0.075288
# Cost After epoch 5 : 0.075462
# Cost After epoch 5 : 0.075640
# Cost After epoch 5 : 0.075936
# Cost After epoch 5 : 0.075992
# Cost After epoch 5 : 0.076524
# Cost After epoch 5 : 0.076731
# Cost After epoch 5 : 0.076874
# Cost After epoch 5 : 0.077483
# Cost After epoch 5 : 0.077735
# Cost After epoch 5 : 0.078235
# Cost After epoch 5 : 0.080348
# Cost After epoch 5 : 0.080413
# Cost After epoch 5 : 0.080443
# Cost After epoch 5 : 0.080537
# Cost After epoch 5 : 0.080713
# Cost After epoch 5 : 0.080764
# Cost After epoch 5 : 0.081778
# Cost After epoch 5 : 0.082397
# Cost After epoch 5 : 0.082519
# Cost After epoch 5 : 0.083902
# Cost After epoch 5 : 0.084558
# Cost After epoch 5 : 0.084636
# Cost After epoch 5 : 0.085433
# Cost After epoch 5 : 0.086201
# Cost After epoch 5 : 0.086393
# Cost After epoch 5 : 0.086491
# Cost After epoch 5 : 0.088391
# Cost After epoch 5 : 0.088902
# Cost After epoch 5 : 0.089018
# Cost After epoch 5 : 0.089335
# Cost After epoch 5 : 0.090294
# Cost After epoch 5 : 0.090402
# Cost After epoch 5 : 0.090433
# Cost After epoch 5 : 0.090569
# Cost After epoch 5 : 0.092611
# Cost After epoch 5 : 0.092646
# Cost After epoch 5 : 0.092702
# Cost After epoch 5 : 0.092713
# Cost After epoch 5 : 0.093223
# Cost After epoch 5 : 0.093464
# Cost After epoch 5 : 0.093552
# Cost After epoch 5 : 0.097525
# Cost After epoch 5 : 0.097649
# Cost After epoch 5 : 0.099876
# Cost After epoch 5 : 0.100569
# Cost After epoch 5 : 0.101194
# Cost After epoch 5 : 0.102723
# Cost After epoch 5 : 0.103777
# Cost After epoch 5 : 0.103867
# Cost After epoch 5 : 0.104044
# Cost After epoch 5 : 0.104573
# Cost After epoch 5 : 0.104596
# Cost After epoch 5 : 0.104680
# Cost After epoch 5 : 0.104685
# Cost After epoch 5 : 0.104840
# Cost After epoch 5 : 0.105342
# Cost After epoch 5 : 0.107606
# Cost After epoch 5 : 0.107626
# Cost After epoch 5 : 0.108162
# Cost After epoch 5 : 0.108496
# Cost After epoch 5 : 0.109308
# Cost After epoch 5 : 0.109381
# Cost After epoch 5 : 0.109471
# Cost After epoch 5 : 0.110967
# Cost After epoch 5 : 0.110969
# Cost After epoch 5 : 0.111131
# Cost After epoch 5 : 0.111307
# Cost After epoch 5 : 0.112416
# Cost After epoch 5 : 0.112928
# Cost After epoch 5 : 0.112934
# Cost After epoch 5 : 0.114205
# Cost After epoch 5 : 0.115564
# Cost After epoch 5 : 0.116071
# Cost After epoch 5 : 0.116077
# Cost After epoch 5 : 0.116338
# Cost After epoch 5 : 0.116504
# Cost After epoch 5 : 0.116999
# Cost After epoch 5 : 0.118168
# Cost After epoch 5 : 0.118509
# Cost After epoch 5 : 0.119353
# Cost After epoch 5 : 0.119742
# Cost After epoch 5 : 0.122165
# Cost After epoch 5 : 0.122278
# Cost After epoch 5 : 0.122599
# Cost After epoch 5 : 0.122638
# Cost After epoch 5 : 0.123298
# Cost After epoch 5 : 0.123466
# Cost After epoch 5 : 0.123559
# Cost After epoch 5 : 0.123593
# Cost After epoch 5 : 0.125143
# Cost After epoch 5 : 0.125184
# Cost After epoch 5 : 0.125297
# Cost After epoch 5 : 0.125491
# Cost After epoch 5 : 0.125547
# Cost After epoch 5 : 0.125576
# Cost After epoch 5 : 0.125595
# Cost After epoch 5 : 0.126088
# Cost After epoch 5 : 0.126321
# Cost After epoch 5 : 0.126820
# Cost After epoch 5 : 0.127222
# Cost After epoch 5 : 0.127288
# Cost After epoch 5 : 0.127882
# Cost After epoch 5 : 0.127905
# Cost After epoch 5 : 0.128974
# Cost After epoch 5 : 0.129848
# Cost After epoch 5 : 0.130167
# Cost After epoch 5 : 0.130191
# Cost After epoch 5 : 0.133031
# Cost After epoch 10 : 0.000002
# Cost After epoch 10 : 0.000006
# Cost After epoch 10 : 0.000012
# Cost After epoch 10 : 0.000133
# Cost After epoch 10 : 0.000163
# Cost After epoch 10 : 0.000251
# Cost After epoch 10 : 0.000578
# Cost After epoch 10 : 0.001609
# Cost After epoch 10 : 0.001636
# Cost After epoch 10 : 0.001649
# Cost After epoch 10 : 0.004045
# Cost After epoch 10 : 0.004053
# Cost After epoch 10 : 0.005133
# Cost After epoch 10 : 0.005291
# Cost After epoch 10 : 0.005293
# Cost After epoch 10 : 0.006200
# Cost After epoch 10 : 0.006230
# Cost After epoch 10 : 0.006249
# Cost After epoch 10 : 0.006280
# Cost After epoch 10 : 0.006318
# Cost After epoch 10 : 0.006365
# Cost After epoch 10 : 0.006416
# Cost After epoch 10 : 0.007177
# Cost After epoch 10 : 0.007250
# Cost After epoch 10 : 0.007294
# Cost After epoch 10 : 0.007502
# Cost After epoch 10 : 0.007661
# Cost After epoch 10 : 0.007686
# Cost After epoch 10 : 0.007946
# Cost After epoch 10 : 0.007962
# Cost After epoch 10 : 0.008214
# Cost After epoch 10 : 0.008380
# Cost After epoch 10 : 0.008398
# Cost After epoch 10 : 0.009741
# Cost After epoch 10 : 0.010475
# Cost After epoch 10 : 0.011514
# Cost After epoch 10 : 0.011564
# Cost After epoch 10 : 0.012827
# Cost After epoch 10 : 0.012828
# Cost After epoch 10 : 0.013864
# Cost After epoch 10 : 0.014662
# Cost After epoch 10 : 0.014663
# Cost After epoch 10 : 0.014914
# Cost After epoch 10 : 0.014915
# Cost After epoch 10 : 0.014942
# Cost After epoch 10 : 0.014953
# Cost After epoch 10 : 0.015141
# Cost After epoch 10 : 0.015216
# Cost After epoch 10 : 0.015218
# Cost After epoch 10 : 0.015364
# Cost After epoch 10 : 0.018132
# Cost After epoch 10 : 0.018411
# Cost After epoch 10 : 0.018448
# Cost After epoch 10 : 0.018475
# Cost After epoch 10 : 0.019785
# Cost After epoch 10 : 0.020077
# Cost After epoch 10 : 0.020078
# Cost After epoch 10 : 0.020085
# Cost After epoch 10 : 0.021309
# Cost After epoch 10 : 0.021312
# Cost After epoch 10 : 0.021580
# Cost After epoch 10 : 0.021718
# Cost After epoch 10 : 0.021724
# Cost After epoch 10 : 0.023651
# Cost After epoch 10 : 0.023821
# Cost After epoch 10 : 0.023861
# Cost After epoch 10 : 0.024046
# Cost After epoch 10 : 0.024076
# Cost After epoch 10 : 0.024084
# Cost After epoch 10 : 0.024089
# Cost After epoch 10 : 0.025252
# Cost After epoch 10 : 0.025467
# Cost After epoch 10 : 0.026067
# Cost After epoch 10 : 0.026483
# Cost After epoch 10 : 0.027330
# Cost After epoch 10 : 0.027605
# Cost After epoch 10 : 0.027978
# Cost After epoch 10 : 0.028355
# Cost After epoch 10 : 0.028745
# Cost After epoch 10 : 0.029802
# Cost After epoch 10 : 0.030244
# Cost After epoch 10 : 0.031118
# Cost After epoch 10 : 0.031274
# Cost After epoch 10 : 0.031932
# Cost After epoch 10 : 0.034175
# Cost After epoch 10 : 0.034186
# Cost After epoch 10 : 0.034314
# Cost After epoch 10 : 0.034957
# Cost After epoch 10 : 0.034977
# Cost After epoch 10 : 0.034989
# Cost After epoch 10 : 0.037478
# Cost After epoch 10 : 0.037938
# Cost After epoch 10 : 0.038000
# Cost After epoch 10 : 0.039329
# Cost After epoch 10 : 0.039543
# Cost After epoch 10 : 0.039568
# Cost After epoch 10 : 0.039761
# Cost After epoch 10 : 0.039761
# Cost After epoch 10 : 0.039771
# Cost After epoch 10 : 0.039928
# Cost After epoch 10 : 0.039941
# Cost After epoch 10 : 0.040453
# Cost After epoch 10 : 0.040453
# Cost After epoch 10 : 0.042944
# Cost After epoch 10 : 0.044088
# Cost After epoch 10 : 0.044090
# Cost After epoch 10 : 0.044095
# Cost After epoch 10 : 0.044284
# Cost After epoch 10 : 0.044291
# Cost After epoch 10 : 0.044305
# Cost After epoch 10 : 0.044347
# Cost After epoch 10 : 0.045722
# Cost After epoch 10 : 0.046540
# Cost After epoch 10 : 0.046752
# Cost After epoch 10 : 0.046792
# Cost After epoch 10 : 0.046874
# Cost After epoch 10 : 0.047411
# Cost After epoch 10 : 0.048337
# Cost After epoch 10 : 0.049060
# Cost After epoch 10 : 0.049136
# Cost After epoch 10 : 0.049276
# Cost After epoch 10 : 0.052645
# Cost After epoch 10 : 0.052712
# Cost After epoch 10 : 0.052853
# Cost After epoch 10 : 0.052998
# Cost After epoch 10 : 0.054189
# Cost After epoch 10 : 0.054560
# Cost After epoch 10 : 0.054702
# Cost After epoch 10 : 0.054705
# Cost After epoch 10 : 0.054864
# Cost After epoch 10 : 0.057999
# Cost After epoch 10 : 0.058649
# Cost After epoch 10 : 0.058794
# Cost After epoch 10 : 0.058806
# Cost After epoch 10 : 0.058903
# Cost After epoch 10 : 0.060009
# Cost After epoch 10 : 0.060610
# Cost After epoch 10 : 0.068269
# Cost After epoch 10 : 0.068929
# Cost After epoch 10 : 0.072013
# Cost After epoch 10 : 0.072015
# Cost After epoch 10 : 0.072352
# Cost After epoch 10 : 0.072819
# Cost After epoch 10 : 0.075026
# Cost After epoch 10 : 0.075684
# Cost After epoch 10 : 0.075957
# Cost After epoch 10 : 0.079697
# Cost After epoch 10 : 0.082144
# Cost After epoch 10 : 0.082852
# Cost After epoch 10 : 0.084621
# Cost After epoch 10 : 0.084672
# Cost After epoch 10 : 0.084674
# Cost After epoch 10 : 0.085074
# Cost After epoch 10 : 0.086268
# Cost After epoch 10 : 0.091589
# Cost After epoch 10 : 0.091608
# Cost After epoch 10 : 0.091671
# Cost After epoch 10 : 0.093208
# Cost After epoch 10 : 0.093218
# Cost After epoch 10 : 0.093430
# Cost After epoch 10 : 0.093835
# Cost After epoch 10 : 0.094080
# Cost After epoch 10 : 0.094081
# Cost After epoch 10 : 0.094480
# Cost After epoch 10 : 0.094534
# Cost After epoch 10 : 0.094602
# Cost After epoch 10 : 0.095120
# Cost After epoch 10 : 0.095139
# Cost After epoch 10 : 0.095149
# Cost After epoch 10 : 0.095177
# Cost After epoch 10 : 0.095280
# Cost After epoch 10 : 0.098687
# Cost After epoch 10 : 0.098734
# Cost After epoch 10 : 0.098737
# Cost After epoch 10 : 0.099403
# Cost After epoch 10 : 0.099406
# Cost After epoch 10 : 0.099420
# Cost After epoch 10 : 0.099484
# Cost After epoch 10 : 0.101268
# Cost After epoch 10 : 0.101275
# Cost After epoch 10 : 0.102093
# Cost After epoch 10 : 0.102256
# Cost After epoch 10 : 0.102357
# Cost After epoch 10 : 0.102363
# Cost After epoch 10 : 0.103040
# Cost After epoch 10 : 0.103089
# Cost After epoch 10 : 0.105242
# Cost After epoch 10 : 0.105388
# Cost After epoch 10 : 0.105416
# Cost After epoch 10 : 0.105885
# Cost After epoch 10 : 0.106627
# Cost After epoch 10 : 0.107935
# Cost After epoch 10 : 0.108955
# Cost After epoch 10 : 0.109033
# Cost After epoch 10 : 0.109291
# Cost After epoch 10 : 0.109450
# Cost After epoch 10 : 0.109469
# Cost After epoch 10 : 0.109488
# Cost After epoch 10 : 0.109625
# Cost After epoch 10 : 0.111012
# Cost After epoch 10 : 0.112209
# Cost After epoch 10 : 0.112348
# Cost After epoch 10 : 0.112350
# Cost After epoch 10 : 0.112449
# Cost After epoch 10 : 0.112596
# Cost After epoch 10 : 0.112624
# Cost After epoch 10 : 0.112695
# Cost After epoch 10 : 0.112715
# Cost After epoch 10 : 0.112870
# Cost After epoch 10 : 0.112879
# Cost After epoch 10 : 0.112885
# Cost After epoch 10 : 0.113369
# Cost After epoch 10 : 0.114494
# Cost After epoch 10 : 0.116327
# Cost After epoch 10 : 0.118451
# Cost After epoch 10 : 0.118655
# Cost After epoch 10 : 0.118662
# Cost After epoch 10 : 0.121036
# Cost After epoch 10 : 0.121076
# Cost After epoch 10 : 0.122884
# Cost After epoch 10 : 0.124143
# Cost After epoch 15 : 0.000027
# Cost After epoch 15 : 0.000088
# Cost After epoch 15 : 0.000213
# Cost After epoch 15 : 0.003377
# Cost After epoch 15 : 0.003406
# Cost After epoch 15 : 0.003530
# Cost After epoch 15 : 0.003535
# Cost After epoch 15 : 0.003721
# Cost After epoch 15 : 0.003721
# Cost After epoch 15 : 0.003774
# Cost After epoch 15 : 0.003774
# Cost After epoch 15 : 0.003892
# Cost After epoch 15 : 0.004177
# Cost After epoch 15 : 0.006664
# Cost After epoch 15 : 0.006768
# Cost After epoch 15 : 0.006774
# Cost After epoch 15 : 0.007544
# Cost After epoch 15 : 0.007918
# Cost After epoch 15 : 0.007933
# Cost After epoch 15 : 0.008022
# Cost After epoch 15 : 0.008215
# Cost After epoch 15 : 0.008224
# Cost After epoch 15 : 0.008227
# Cost After epoch 15 : 0.008256
# Cost After epoch 15 : 0.008476
# Cost After epoch 15 : 0.008500
# Cost After epoch 15 : 0.008527
# Cost After epoch 15 : 0.008581
# Cost After epoch 15 : 0.008657
# Cost After epoch 15 : 0.008677
# Cost After epoch 15 : 0.008697
# Cost After epoch 15 : 0.008763
# Cost After epoch 15 : 0.008802
# Cost After epoch 15 : 0.009874
# Cost After epoch 15 : 0.009913
# Cost After epoch 15 : 0.009998
# Cost After epoch 15 : 0.010420
# Cost After epoch 15 : 0.010420
# Cost After epoch 15 : 0.010431
# Cost After epoch 15 : 0.010439
# Cost After epoch 15 : 0.011743
# Cost After epoch 15 : 0.011768
# Cost After epoch 15 : 0.011773
# Cost After epoch 15 : 0.011775
# Cost After epoch 15 : 0.011776
# Cost After epoch 15 : 0.012719
# Cost After epoch 15 : 0.012726
# Cost After epoch 15 : 0.012780
# Cost After epoch 15 : 0.012939
# Cost After epoch 15 : 0.013275
# Cost After epoch 15 : 0.013323
# Cost After epoch 15 : 0.013333
# Cost After epoch 15 : 0.013338
# Cost After epoch 15 : 0.013594
# Cost After epoch 15 : 0.013897
# Cost After epoch 15 : 0.013927
# Cost After epoch 15 : 0.013960
# Cost After epoch 15 : 0.013961
# Cost After epoch 15 : 0.013962
# Cost After epoch 15 : 0.013963
# Cost After epoch 15 : 0.014012
# Cost After epoch 15 : 0.014013
# Cost After epoch 15 : 0.014185
# Cost After epoch 15 : 0.014602
# Cost After epoch 15 : 0.014623
# Cost After epoch 15 : 0.014643
# Cost After epoch 15 : 0.014916
# Cost After epoch 15 : 0.014920
# Cost After epoch 15 : 0.014991
# Cost After epoch 15 : 0.015126
# Cost After epoch 15 : 0.015133
# Cost After epoch 15 : 0.015135
# Cost After epoch 15 : 0.015188
# Cost After epoch 15 : 0.015307
# Cost After epoch 15 : 0.015385
# Cost After epoch 15 : 0.015406
# Cost After epoch 15 : 0.015523
# Cost After epoch 15 : 0.015535
# Cost After epoch 15 : 0.016649
# Cost After epoch 15 : 0.017555
# Cost After epoch 15 : 0.017556
# Cost After epoch 15 : 0.017556
# Cost After epoch 15 : 0.017614
# Cost After epoch 15 : 0.017635
# Cost After epoch 15 : 0.017655
# Cost After epoch 15 : 0.017676
# Cost After epoch 15 : 0.018033
# Cost After epoch 15 : 0.018100
# Cost After epoch 15 : 0.018934
# Cost After epoch 15 : 0.018935
# Cost After epoch 15 : 0.019151
# Cost After epoch 15 : 0.019161
# Cost After epoch 15 : 0.019194
# Cost After epoch 15 : 0.019199
# Cost After epoch 15 : 0.019201
# Cost After epoch 15 : 0.019277
# Cost After epoch 15 : 0.019282
# Cost After epoch 15 : 0.019303
# Cost After epoch 15 : 0.019304
# Cost After epoch 15 : 0.019328
# Cost After epoch 15 : 0.019356
# Cost After epoch 15 : 0.021906
# Cost After epoch 15 : 0.021920
# Cost After epoch 15 : 0.021933
# Cost After epoch 15 : 0.022364
# Cost After epoch 15 : 0.022366
# Cost After epoch 15 : 0.022391
# Cost After epoch 15 : 0.023238
# Cost After epoch 15 : 0.023374
# Cost After epoch 15 : 0.023380
# Cost After epoch 15 : 0.023566
# Cost After epoch 15 : 0.023570
# Cost After epoch 15 : 0.023582
# Cost After epoch 15 : 0.026342
# Cost After epoch 15 : 0.026506
# Cost After epoch 15 : 0.026519
# Cost After epoch 15 : 0.027064
# Cost After epoch 15 : 0.027112
# Cost After epoch 15 : 0.027127
# Cost After epoch 15 : 0.027436
# Cost After epoch 15 : 0.027472
# Cost After epoch 15 : 0.027578
# Cost After epoch 15 : 0.027594
# Cost After epoch 15 : 0.027617
# Cost After epoch 15 : 0.027685
# Cost After epoch 15 : 0.028001
# Cost After epoch 15 : 0.028001
# Cost After epoch 15 : 0.028011
# Cost After epoch 15 : 0.029522
# Cost After epoch 15 : 0.029528
# Cost After epoch 15 : 0.029861
# Cost After epoch 15 : 0.029863
# Cost After epoch 15 : 0.029863
# Cost After epoch 15 : 0.029865
# Cost After epoch 15 : 0.029867
# Cost After epoch 15 : 0.029872
# Cost After epoch 15 : 0.031201
# Cost After epoch 15 : 0.031206
# Cost After epoch 15 : 0.031240
# Cost After epoch 15 : 0.031265
# Cost After epoch 15 : 0.031272
# Cost After epoch 15 : 0.031314
# Cost After epoch 15 : 0.031317
# Cost After epoch 15 : 0.031477
# Cost After epoch 15 : 0.031481
# Cost After epoch 15 : 0.031547
# Cost After epoch 15 : 0.033100
# Cost After epoch 15 : 0.034667
# Cost After epoch 15 : 0.035588
# Cost After epoch 15 : 0.036486
# Cost After epoch 15 : 0.036673
# Cost After epoch 15 : 0.036717
# Cost After epoch 15 : 0.037290
# Cost After epoch 15 : 0.037293
# Cost After epoch 15 : 0.037294
# Cost After epoch 15 : 0.037295
# Cost After epoch 15 : 0.038031
# Cost After epoch 15 : 0.038031
# Cost After epoch 15 : 0.038032
# Cost After epoch 15 : 0.038495
# Cost After epoch 15 : 0.038930
# Cost After epoch 15 : 0.039190
# Cost After epoch 15 : 0.040762
# Cost After epoch 15 : 0.040958
# Cost After epoch 15 : 0.041774
# Cost After epoch 15 : 0.041775
# Cost After epoch 15 : 0.042516
# Cost After epoch 15 : 0.043837
# Cost After epoch 15 : 0.046188
# Cost After epoch 15 : 0.046362
# Cost After epoch 15 : 0.046367
# Cost After epoch 15 : 0.046372
# Cost After epoch 15 : 0.046559
# Cost After epoch 15 : 0.046559
# Cost After epoch 15 : 0.046891
# Cost After epoch 15 : 0.046892
# Cost After epoch 15 : 0.047275
# Cost After epoch 15 : 0.047313
# Cost After epoch 15 : 0.048025
# Cost After epoch 15 : 0.048074
# Cost After epoch 15 : 0.048146
# Cost After epoch 15 : 0.048470
# Cost After epoch 15 : 0.048874
# Cost After epoch 15 : 0.048880
# Cost After epoch 15 : 0.048953
# Cost After epoch 15 : 0.049153
# Cost After epoch 15 : 0.049199
# Cost After epoch 15 : 0.050440
# Cost After epoch 15 : 0.050464
# Cost After epoch 15 : 0.050499
# Cost After epoch 15 : 0.050579
# Cost After epoch 15 : 0.050579
# Cost After epoch 15 : 0.050628
# Cost After epoch 15 : 0.050779
# Cost After epoch 15 : 0.050896
# Cost After epoch 15 : 0.051445
# Cost After epoch 15 : 0.051593
# Cost After epoch 15 : 0.051624
# Cost After epoch 15 : 0.051637
# Cost After epoch 15 : 0.053629
# Cost After epoch 15 : 0.053661
# Cost After epoch 15 : 0.053665
# Cost After epoch 15 : 0.053730
# Cost After epoch 15 : 0.053736
# Cost After epoch 15 : 0.054356
# Cost After epoch 15 : 0.054365
# Cost After epoch 15 : 0.056454
# Cost After epoch 15 : 0.056463
# Cost After epoch 15 : 0.056867
# Cost After epoch 15 : 0.057261
# Cost After epoch 15 : 0.059118
# Cost After epoch 15 : 0.059190
# Cost After epoch 15 : 0.059250
# Cost After epoch 15 : 0.059363
# Cost After epoch 15 : 0.059391
# Cost After epoch 15 : 0.059449
# Cost After epoch 15 : 0.059466
# Cost After epoch 15 : 0.061032
# Cost After epoch 15 : 0.061041
# Cost After epoch 15 : 0.062691
# Cost After epoch 15 : 0.064008
# Tensor("Mean_1:0", shape=(), dtype=float32)
# Train Accuracy: 0.9852775
# Test Accuracy: 0.96887845
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./xoxo2/saved_model.pb'

# %%
#test
inferencing_input = load_images_for_inferencing('input')
print (inferencing_input.shape)

# %%
from tensorflow.core.framework import graph_pb2
with tf.Session(graph = tf.Graph()) as sess:
    tf.saved_model.loader.load(sess, ["serve"],'./xoxo/')
    
    graph = tf.get_default_graph()
    #print (graph.get_operations())
    graph_def = graph_pb2.GraphDef()
    
#     with open(FLAGS.graph,'rb') as f:
#         if FLAGS.input_binary:
#             graph_def.ParseFromString(f.read())
#         else:
#             text_format.Merge(f.read(), graph_def)
      
#     for node in graph_def.node:
#         print(node)
            
    
    print (sess.run('predict_op:0',feed_dict = {'myInput:0':inferencing_input}))
